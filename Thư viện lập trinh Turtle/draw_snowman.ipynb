# %%
import turtle 
# 
screen=turtle.Screen()
screen.bgcolor('lightblue') # màu background 
t=turtle.Turtle()
t.hideturtle()
t.pensize(1)
t.speed()

t.penup()
t.goto(0,-175)
t.pendown()

t.color('black')
t.fillcolor('white')
t.begin_fill()
t.circle(100)
t.end_fill()

t.penup()
t.home()
t.pendown()

t.color('black')
t.fillcolor('white')
t.begin_fill()
t.circle(50)
t.end_fill()

t.penup()
t.goto(-60,80)
t.pendown()

t.color('black')
t.pensize(1)
t.fillcolor('brown')
t.begin_fill()
t.forward(120)
t.left(90)
t.forward(20)
t.left(90)
t.forward(120)
t.left(90)
t.forward(20)
t.left(90)
t.end_fill()

t.penup()
t.goto(-40,100)
t.pendown()

t.color('black')
t.pensize(1)
t.fillcolor('brown')
t.begin_fill()
t.forward(80)
t.left(90)
t.forward(50)
t.left(90)
t.forward(80)
t.left(90)
t.forward(50)
t.left(90)
t.end_fill()

t.penup()
t.goto(100,-50)
t.pendown()

t.color('black')
t.pensize(4)
t.left(45)
t.forward(50)
t.left(45)
t.forward(10)
t.backward(10)
t.right(90)
t.forward(20)

t.penup()
t.goto(-100,-50)
t.pendown()

t.color('black')
t.pensize(4)
t.left(145)
t.forward(50)
t.right(45)
t.forward(10)
t.backward(10)
t.left(90)
t.forward(20)

t.penup()
t.goto(-20,62)
t.pendown()

t.color('black')
t.fillcolor('black')
t.begin_fill()
t.circle(5)
t.end_fill()

t.penup()
t.goto(20,62)
t.pendown()

t.color('black')
t.fillcolor('black')
t.begin_fill()
t.circle(5)
t.end_fill()

t.penup()
t.goto(0,30)
t.pendown()

t.color('orange')
t.fillcolor('orange')
t.begin_fill()
t.left(10)
t.forward(20)
t.left(160)
t.forward(20)
t.circle(5)
t.end_fill()

t.penup()
t.goto(0,-50)
t.pendown()

t.color('black')
t.fillcolor('black')
t.begin_fill()
t.circle(5)
t.end_fill()

t.penup()
t.goto(0,-85)
t.pendown()

t.color('black')
t.fillcolor('black')
t.begin_fill()
t.circle(5)
t.end_fill()

t.penup()
t.goto(0,-110)
t.pendown()

t.color('black')
t.fillcolor('black')
t.begin_fill()
t.circle(5)
t.end_fill()
#vẽ tuyết 
t.penup()
t.goto(100,110)
t.pendown()
t.color('white')
t.fillcolor('white')
t.begin_fill()
t.circle(5)
t.end_fill()

t.penup()
t.goto(-95,110)
t.pendown()
t.color('white')
t.fillcolor('white')
t.begin_fill()
t.circle(5)
t.end_fill()

t.penup()
t.goto(-90,130)
t.pendown()
t.color('white')
t.fillcolor('white')
t.begin_fill()
t.circle(6)
t.end_fill()

t.penup()
t.goto(-120,100)
t.pendown()
t.color('white')
t.fillcolor('white')
t.begin_fill()
t.circle(4)
t.end_fill()

t.penup()
t.goto(120,120)
t.pendown()
t.color('white')
t.fillcolor('white')
t.begin_fill()
t.circle(6)
t.end_fill()


#kết thúc 
turtle.done()
